# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fa2c57e3-9f02-4d0c-8f5a-8e5448e53541" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa2c57e3-9f02-4d0c-8f5a-8e5448e53541">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("train.csv")

df.shape
# Out:
# (9800, 18)

# %%
df.head(3)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08-11-2017  11-11-2017  Second Class    CG-12520
# 1       2  CA-2017-152156  08-11-2017  11-11-2017  Second Class    CG-12520
# 2       3  CA-2017-138688  12-06-2017  16-06-2017  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City       State  \
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales
# ...

# %% [markdown]
# ## Project 1

# %%
# 1. Total number of orders

len(df["Order ID"].value_counts())

# out of 9800 records total hald them are orders are recorded.
# Out:
# 4922

# %%
# 2. Total number of unique customers

len(df["Customer Name"].unique())

# total unique customers are 793 out of 9800.
# Out:
# 793

# %%
# 3. Number of categories

len(df["Category"].unique())

# total 3 categories are rulling the entire 9800 sales
# Out:
# 3

# %%
# 4. Number of sub-categories

len(df["Sub-Category"].unique())

# 3 categories and containing 17 sub categories
# Out:
# 17

# %%
# 5. Highest sales value

df["Sales"].sort_values(ascending = False).head(1)

# Highest sale amount 9800 records is 22638.48
# Out:
# 2697    22638.48
# Name: Sales, dtype: float64

# %%
df["Sales"].max() # if only top 1 is asked we can use max. or for multiple we must use sort.
# Out:
# 22638.48

# %%
# 6. Lowest sales value

df["Sales"].sort_values().head(1)

# Lowest sale amount 9800 records is 0.444
# Out:
# 4101    0.444
# Name: Sales, dtype: float64

# %%
df["Sales"].min() # if only least 1 is asked we can use min. or for multiple we must use sort.
# Out:
# 0.444

# %%
# 7. Average sales value

print(df["Sales"].mean())

# out of 9800 records the average sale was sale was 230.7690594591837
# Out:
# 230.7690594591837

# %% [markdown]
# # Poject 2

# %%
# Which category has the highest number of sales records?

df.groupby("Category")["Sales"].sum().sort_values(ascending= False)

# we can find that Tchnology is having highest sales compared to other categories.
# Out:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64

# %%
# Which sub-category appears most frequently?

df["Sub-Category"].value_counts().head(1)

# Highest sub_category appered more frequent is Binders with total 1492 times
# Out:
# Sub-Category
# Binders    1492
# Name: count, dtype: int64

# %%
# Show the Top 5 highest sales transactions.

df.sort_values("Sales", ascending= False).head(5)

# complete rows of top 5 highest sale transaction

# All high transactions are been done in the category of Technology as feequent appered sub-category was Copiers.
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2015-145317  18-03-2015  23-03-2015  Standard Class
# 6826    6827  CA-2017-118689  02-10-2017  09-10-2017  Standard Class
# 8153    8154  CA-2018-140151  23-03-2018  25-03-2018     First Class
# 2623    2624  CA-2018-127180  22-10-2018  24-10-2018     First Class
# 4190    4191  CA-2018-166709  17-11-2018  22-11-2018  Standard Class
#
#      Customer ID Customer Name      Segment        Country           City  \
# 2697    SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 6826    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 8153    RB-19360  Raymond Buch     Consumer  United States        Seattle
# 2623    TA-21385  Tom Ashbrook  Home Office  United States  New York City
# 4190    HL-15040  Hunter Lopez     Consumer  United States         Newark
#
#            State  Postal Code   Region       Product ID    Category  \
# ...

# %%
# Show the Top 5 lowest sales transactions.

df.sort_values("Sales").head(5)

# complete rows of top 5 lowest sale transaction

# All low transactions are been done in the category of Office Supplies as feequent appered sub-category was Binders.
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 4101    4102  US-2018-102288  19-06-2018  23-06-2018  Standard Class
# 9292    9293  CA-2018-124114  02-03-2018  02-03-2018        Same Day
# 8658    8659  CA-2017-168361  21-06-2017  25-06-2017  Standard Class
# 4711    4712  CA-2015-112403  31-03-2015  31-03-2015        Same Day
# 2106    2107  US-2015-152723  26-09-2015  26-09-2015        Same Day
#
#      Customer ID     Customer Name    Segment        Country          City  \
# 4101    ZC-21910  Zuschuss Carroll   Consumer  United States       Houston
# 9292    RS-19765    Roland Schwarz  Corporate  United States          Waco
# 8658    KB-16600       Ken Brennan  Corporate  United States       Chicago
# 4711    JO-15280     Jas O'Carroll   Consumer  United States  Philadelphia
# 2106    HG-14965     Henry Goldwyn  Corporate  United States      Mesquite
#
#              State  Postal Code   Region       Product ID         Category  \
# ...

# %%
# Which region appears most frequently?

df["City"].value_counts().head(3)

# New York City was the region appears most frequently
# Out:
# City
# New York City    891
# Los Angeles      728
# Philadelphia     532
# Name: count, dtype: int64

# %% [markdown]
# # Project 3

# %%
# Which customer generated the highest total sales?

df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(1)
# Sean Miller is the customer with total highest sales with 25043.05.
# Out:
# Customer Name
# Sean Miller    25043.05
# Name: Sales, dtype: float64

# %%
# Top 5 customers by total sales.

df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(5)

# only customer who has spend more than 20000 is Sean Miller out of top 5. rest all are in between 14000 to 20000
# Out:
# Customer Name
# Sean Miller      25043.050
# Tamara Chand     19052.218
# Raymond Buch     15117.339
# Tom Ashbrook     14595.620
# Adrian Barton    14473.571
# Name: Sales, dtype: float64

# %%
# Which state generated the highest total sales?

df.groupby("State")["Sales"].sum().sort_values(ascending=False).head(1)

# California generated the highest total with sales of 446306.4635
# Out:
# State
# California    446306.4635
# Name: Sales, dtype: float64

# %%
# Which region generated the highest total sales?

df.groupby("Region")["Sales"].sum().sort_values(ascending=False).head(1)

# West region generated the highest total with sales of 710219.6845
# Out:
# Region
# West    710219.6845
# Name: Sales, dtype: float64

# %%
# Which ship mode is used most frequently?

df["Ship Mode"].value_counts().head(1)

# most frequently used ship mode was Standard Class with a count of 5859.
# Out:
# Ship Mode
# Standard Class    5859
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08-11-2017  11-11-2017  Second Class    CG-12520
# 1       2  CA-2017-152156  08-11-2017  11-11-2017  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City     State  Postal Code  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
# 1   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
#
#   Region       Product ID   Category Sub-Category  \
# 0  South  FUR-BO-10001798  Furniture    Bookcases
# 1  South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94

# %% [markdown]
# # Project 4

# %%
# Which year generated the highest total sales?

df["Order Date"] = pd.to_datetime(df["Order Date"])

df["year"] = df["Order Date"].dt.year

df.groupby("year")["Sales"].sum().sort_values(ascending=False).head(1)

# 2018 has generated highest total sales of 722052.0192
# Out:
# year
# 2018    722052.0192
# Name: Sales, dtype: float64

# %%
# Top 5 cities by total sales.

df.groupby("City")["Sales"].sum().sort_values(ascending=False).head(5)

# New york topped in total sales compared to other cities followed with Los Angeles, Seattle, San Francisco and Philadelphia. Top 1st city is more than twice to the top 5th city.
# Out:
# City
# New York City    252462.547
# Los Angeles      173420.181
# Seattle          116106.322
# San Francisco    109041.120
# Philadelphia     108841.749
# Name: Sales, dtype: float64

# %%
# Top 5 states by total sales.

df.groupby("State")["Sales"].sum().sort_values(ascending=False).head(5)

# California topped in ttal sales compared to other cities followed with New York, Texas, Washington and Washington. Top 1st State is almost4 times to the top 5th city.
# Out:
# State
# California      446306.4635
# New York        306361.1470
# Texas           168572.5322
# Washington      135206.8500
# Pennsylvania    116276.6500
# Name: Sales, dtype: float64

# %%
# Which segment generated the highest total sales?

df.groupby("Segment")["Sales"].sum().sort_values(ascending=False).head(1)

# Consumer segment generated the highest total sales of 1148060.531
# Out:
# Segment
# Consumer    1148060.531
# Name: Sales, dtype: float64

# %%
# Which category generated the highest total sales?

df.groupby("Category")["Sales"].sum().sort_values(ascending=False).head(1)

# Technology generated the highest total sales of 827455.873
# Out:
# Category
# Technology    827455.873
# Name: Sales, dtype: float64

# %%
# Which Sub-Category generated the highest total sales?

df.groupby("Sub-Category")["Sales"].sum().sort_values(ascending=False).head(1)

# Phones are having the highest sales with 327782.448, where we can increase the production of phones and work on other inventory too
# Out:
# Sub-Category
# Phones    327782.448
# Name: Sales, dtype: float64

# %%
df.groupby("Segment")["Sales"].sum().sort_values().head(1)
# Out:
# Segment
# Home Office    424982.1769
# Name: Sales, dtype: float64

# %% [markdown]
# # Project 5

# %%
# Which ship mode generated the highest total sales?

df.groupby("Ship Mode")["Sales"].sum().sort_values(ascending=False).head(1)

# Standard Class ship mode generated the highest total sales with 1340831.307
# Out:
# Ship Mode
# Standard Class    1340831.307
# Name: Sales, dtype: float64

# %%
# Top 5 products by total sales.

df.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(5)

# The top 5 products contribute significantly to overall revenue. The highest-selling product generated Canon imageCLASS 2200 Advanced Copier sales of 61599.824, indicating strong customer demand.
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# Name: Sales, dtype: float64

# %%
# Top 5 cities by average sales

df.groupby("City")["Sales"].mean().sort_values(ascending=False).head(5)

# Jamestown was topped among other cities with average sales of 2354.395 followed by Cheyenne, Bellingham, Independence and Burbank
# Out:
# City
# Jamestown       2354.395000
# Cheyenne        1603.136000
# Bellingham      1263.413333
# Independence    1208.685000
# Burbank         1082.386000
# Name: Sales, dtype: float64

# %% [markdown]
# # Project Summary

# %% [markdown]
# # Findings 1
#
# #### 2018 generated the highest total sales with 722052.0192.2018 generated the highest total sales with 722052.0192.
#
# # Finding 2
#
# #### November generated the highest total sales with 350161.711.
#
# # Finding 3
#
# #### February generated the lowest total sales with 59371.1154.
#
# # Finding 4
#
# #### Technology generated the highest total sales with 827455.873.
#
# # Finding 5
#
# #### Phones generated the highest total sales with 327782.448.
#
# # Finding 6
#
# #### Highest sales state?
#
# # Finding 7
#
# #### West generated the highest total sales with 710219.6845.
#
# # Finding 8
#
# #### Sean Miller generated the highest total sales with 25043.05.
#
# # Finding 9
#
# #### Standard Class was the most frequently used shipping mode.
#
# # Finding 10
#
# #### Canon imageCLASS 2200 Advanced Copier generated the highest product sales with 61599.824.

# %% [markdown]
# # Recommendations
#
# Recommendation 1
#
# Increase inventory planning and promotional efforts before November and December because these months consistently generate the highest sales.
#
# Recommendation 2
#
# Focus marketing and sales efforts on Technology products, especially Phones, as they contribute the highest revenue.
#
# Recommendation 3
#
# Analyze the reasons behind low February sales and consider seasonal campaigns or discounts to improve performance.
